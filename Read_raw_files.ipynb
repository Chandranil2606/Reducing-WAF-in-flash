# %%
path_to_file = r'C:\Users\cchak\Desktop\New SSD traces\ssdtrace-01\ssdtrace-01'
counter = 0
with open(path_to_file) as f:
    while(counter < 100):
        first_line = f.readline()
        print(first_line)
        counter = counter + 1
# Out:
# 259,2    6  2909518  1227.615207476  4025  U   N [java] 1
#
# 259,2    6  2909519  1227.615207655  4025  I  RS 479020216 + 16 [java]
#
# 259,2    6  2909520  1227.615208399  4025  D  RS 479020216 + 16 [java]
#
# 259,2    2  2718641  1227.615217907     0  C  RS 505785568 + 16 [0]
#
# 259,2   10  2971293  1227.615224386     0  C  RS 110708264 + 16 [0]
#
# 259,2   27  2637499  1227.615230795     0  C  RS 151805624 + 16 [0]
#
# 259,2    1  2733141  1227.615243414  4028  Q   R 856700136 + 8 [java]
#
# 259,2    1  2733142  1227.615244025  4028  G   R 856700136 + 8 [java]
#
# 259,2    1  2733143  1227.615245164  4028  U   N [java] 1
#
# 259,2    1  2733144  1227.615245405  4028  I  RS 856700136 + 8 [java]
#
# 259,2   22  2484582  1227.615245635     0  C  RS 549224296 + 8 [0]
#
# 259,2    1  2733145  1227.615246304  4028  D  RS 856700136 + 8 [java]
#
# 259,2   25  2675006  1227.615265147     0  C  RS 917810136 + 16 [0]
#
# ...

# %%
myline = f.readline()
while myline:
    print(myline)
    myline = myfile.readline()
myfile.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-988e183538ad> in <module>
# ----> 1 myline = f.readline()
#       2 while myline:
#       3     print(myline)
#       4     myline = myfile.readline()
#       5 myfile.close()
#
# ValueError: I/O operation on closed file.

# %%
first_line
# Out:
# '259,2   10   451612   346.224739572  4031  U   N [java] 1\n'

# %%
"W" in first_line
# Out:
# False
